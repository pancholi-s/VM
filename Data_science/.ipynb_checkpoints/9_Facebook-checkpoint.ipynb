# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../DSBDAL_Exam_DataSets/dataset_Facebook.csv", sep=";")
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %% [markdown]
# # Create data subsets for type of post

# %%
df["Type"].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
df_photo = df[df["Type"]=="Photo"]
df_photo.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
df_status = df[df["Type"]=="Status"]
df_status.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df_link = df[df["Type"]=="Link"]
df_link.head()
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df_video = df[df["Type"] == "Video"]
df_video.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Merge two subsets

# %%
df_merged = pd.concat([df_photo, df_status])
df_merged.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
df_photo.shape
# Out:
# (426, 19)

# %%
df_status.shape
# Out:
# (45, 19)

# %%
df_merged.shape
# Out:
# (471, 19)

# %% [markdown]
# # Sort Data on Page Total Likes

# %%
df_sort_likes = df.sort_values(by="like")
df_sort_likes
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
df_sort_comments = df.sort_values(by="comment", ascending=False)
df_sort_comments
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 288            126141  Photo         1           6             4         12
# 228            131728  Photo         2           7             4          3
# ..                ...    ...       ...         ...           ...        ...
# 332            119198  Photo         3           5             2         12
# 333            119198  Photo         3           5             2          1
# 111            136736  Photo         1          10             6          8
# 103            137020  Photo         1          10             3          4
# 499             81370  Photo         2           1             4          4
#
# ...

# %% [markdown]
# # Transposing

# %%
df_transpose = df.transpose()
df_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# # Shape and Reshape

# %%
# adding an index column to provide a unique value to each row entry to further melt and unmelt the data

df["index"] = range(1, len(df)+1)
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Melting data to long format

# %%
df_melt = pd.melt(df, id_vars=['Type', 'Category'], var_name='Metrics', value_name='Value')
df_melt
# Out:
#         Type  Category           Metrics     Value
# 0      Photo         2  Page total likes  139441.0
# 1     Status         2  Page total likes  139441.0
# 2      Photo         3  Page total likes  139441.0
# 3      Photo         2  Page total likes  139441.0
# 4      Photo         2  Page total likes  139441.0
# ...      ...       ...               ...       ...
# 8995   Photo         3             index     496.0
# 8996   Photo         2             index     497.0
# 8997   Photo         1             index     498.0
# 8998   Photo         3             index     499.0
# 8999   Photo         2             index     500.0
#
# [9000 rows x 4 columns]

# %%
df_melt = pd.melt(df, id_vars='index', value_vars='Total Interactions')
df_melt
# Out:
#      index            variable  value
# 0        1  Total Interactions    100
# 1        2  Total Interactions    164
# 2        3  Total Interactions     80
# 3        4  Total Interactions   1777
# 4        5  Total Interactions    393
# ..     ...                 ...    ...
# 495    496  Total Interactions     84
# 496    497  Total Interactions     75
# 497    498  Total Interactions    115
# 498    499  Total Interactions    136
# 499    500  Total Interactions    119
#
# [500 rows x 3 columns]

# %%
df_melt = pd.melt(df, id_vars='index', value_vars='Type')
df_melt
# Out:
#      index variable   value
# 0        1     Type   Photo
# 1        2     Type  Status
# 2        3     Type   Photo
# 3        4     Type   Photo
# 4        5     Type   Photo
# ..     ...      ...     ...
# 495    496     Type   Photo
# 496    497     Type   Photo
# 497    498     Type   Photo
# 498    499     Type   Photo
# 499    500     Type   Photo
#
# [500 rows x 3 columns]

# %% [markdown]
# # Casting to wide format

# %%
df_cast = pd.pivot_table(df, index=['Type', 'Category'], values='like', aggfunc=list)
df_cast
# Out:
#                                                               like
# Type   Category
# Link   1         [16.0, 187.0, 29.0, 57.0, 18.0, 12.0, 130.0, 3...
#        2                                                    [32.0]
#        3                                                    [68.0]
# Photo  1         [678.0, 0.0, 56.0, 76.0, 44.0, 26.0, 47.0, 77....
#        2         [79.0, 1572.0, 325.0, 88.0, 90.0, 137.0, 577.0...
#        3         [66.0, 249.0, 325.0, 113.0, 40.0, 34.0, 72.0, ...
# Status 1                                      [174.0, 210.0, 25.0]
#        2         [130.0, 152.0, 161.0, 233.0, 86.0, 99.0, 88.0,...
#        3                                [54.0, 226.0, 99.0, 227.0]
# Video  1           [143.0, 65.0, 449.0, 99.0, 345.0, 315.0, 204.0]
