# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../DSBDAL_Exam_DataSets/Adult/adult.csv')
df
# Out:
#        Age          Workclass  FnlWgt    Education  Education Num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head()
# Out:
#    Age          Workclass  FnlWgt   Education  Education Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours Per Week  Native Country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   Workclass       32561 non-null  object
#  2   FnlWgt          32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education Num   32561 non-null  int64
#  5   Marital Status  32561 non-null  object
#  6   Occupation      32561 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Race            32561 non-null  object
#  9   Sex             32561 non-null  object
#  10  Capital Gain    32561 non-null  int64
#  11  Capital Loss    32561 non-null  int64
#  12  Hours Per Week  32561 non-null  int64
#  13  Native Country  32561 non-null  object
#  14  Income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # Subsets

# %%
df['Sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df_male = df[df['Sex']==' Male']
df_male
# Out:
#        Age          Workclass  FnlWgt      Education  Education Num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32553   32            Private  116138        Masters             14
# 32554   53            Private  321865        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32557   40            Private  154374        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
#
#             Marital Status          Occupation    Relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# ...

# %%
df_female = df[df['Sex']==' Female']
df_female
# Out:
#        Age      Workclass  FnlWgt      Education  Education Num  \
# 4       28        Private  338409      Bachelors             13
# 5       37        Private  284582        Masters             14
# 6       49        Private  160187            9th              5
# 8       31        Private   45781        Masters             14
# 12      23        Private  122272      Bachelors             13
# ...    ...            ...     ...            ...            ...
# 32546   37        Private  198216     Assoc-acdm             12
# 32549   43      State-gov  255835   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32558   58        Private  151910        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#                Marital Status        Occupation     Relationship    Race  \
# 4          Married-civ-spouse    Prof-specialty             Wife   Black
# ...

# %%
df['Race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df_white = df[df['Race']==' White']
df_white
# Out:
#        Age          Workclass  FnlWgt    Education  Education Num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 5       37            Private  284582      Masters             14
# 7       52   Self-emp-not-inc  209642      HS-grad              9
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df_black = df[df['Race']==' Black']
df_black
# Out:
#        Age Workclass  FnlWgt      Education  Education Num  \
# 3       53   Private  234721           11th              7
# 4       28   Private  338409      Bachelors             13
# 6       49   Private  160187            9th              5
# 10      37   Private  280464   Some-college             10
# 13      32   Private  205019     Assoc-acdm             12
# ...    ...       ...     ...            ...            ...
# 32521   33   Private  273243        HS-grad              9
# 32535   22   Private  325033           12th              8
# 32537   30   Private  345898        HS-grad              9
# 32538   38   Private  139180      Bachelors             13
# 32541   41         ?  202822        HS-grad              9
#
#                Marital Status          Occupation    Relationship    Race  \
# 3          Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4          Married-civ-spouse      Prof-specialty            Wife   Black
# ...

# %%
df['Native Country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df_us = df[df['Native Country'] == ' United-States']
df_us
# Out:
#        Age          Workclass  FnlWgt    Education  Education Num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 5       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df_india = df[df['Native Country'] == ' India']
df_india
# Out:
#        Age          Workclass  FnlWgt    Education  Education Num  \
# 11      30          State-gov  141297    Bachelors             13
# 892     28            Private  164170    Assoc-voc             11
# 968     48            Private  164966    Bachelors             13
# 1029    48       Self-emp-inc  138370      Masters             14
# 1095    22   Self-emp-not-inc  361280    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 30152   48            Private  119471    Doctorate             16
# 30833   25            Private  110978   Assoc-acdm             12
# 30871   26            Private  160261      Masters             14
# 31327   38          State-gov  125499    Bachelors             13
# 31357   23            Private  143003      Masters             14
#
#                Marital Status        Occupation    Relationship  \
# 11         Married-civ-spouse    Prof-specialty         Husband
# ...

# %% [markdown]
# # Merge

# %%
df_concat1 = pd.concat([df_male, df_female])
df_concat1
# Out:
#        Age          Workclass  FnlWgt      Education  Education Num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32546   37            Private  198216     Assoc-acdm             12
# 32549   43          State-gov  255835   Some-college             10
# 32556   27            Private  257302     Assoc-acdm             12
# 32558   58            Private  151910        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#             Marital Status          Occupation     Relationship    Race  \
# 0            Never-married        Adm-clerical    Not-in-family   White
# ...

# %%
df_concat2 = pd.concat([df_white, df_black])
df_concat2
# Out:
#        Age          Workclass  FnlWgt   Education  Education Num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 5       37            Private  284582     Masters             14
# 7       52   Self-emp-not-inc  209642     HS-grad              9
# ...    ...                ...     ...         ...            ...
# 32521   33            Private  273243     HS-grad              9
# 32535   22            Private  325033        12th              8
# 32537   30            Private  345898     HS-grad              9
# 32538   38            Private  139180   Bachelors             13
# 32541   41                  ?  202822     HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# # Sort

# %%
df_sort = df.sort_values('Age')
df_sort
# Out:
#        Age          Workclass  FnlWgt      Education  Education Num  \
# 12318   17            Private  127366           11th              7
# 6312    17            Private  132755           11th              7
# 30927   17            Private  108470           11th              7
# 12787   17          Local-gov  308901           11th              7
# 25755   17                  ?   47407           11th              7
# ...    ...                ...     ...            ...            ...
# 24043   90   Self-emp-not-inc   82628        HS-grad              9
# 32277   90            Private  313749        HS-grad              9
# 5104    90            Private   52386   Some-college             10
# 8963    90                  ?   77053        HS-grad              9
# 10210   90   Self-emp-not-inc  282095   Some-college             10
#
#             Marital Status        Occupation    Relationship  \
# 12318        Never-married             Sales       Own-child
# ...

# %%
df_sort = df.sort_values('Age', ascending=False)
df_sort
# Out:
#        Age Workclass  FnlWgt   Education  Education Num       Marital Status  \
# 5406    90   Private   51744     Masters             14        Never-married
# 6624    90   Private  313986        11th              7   Married-civ-spouse
# 20610   90   Private  206667     Masters             14   Married-civ-spouse
# 1040    90   Private  137018     HS-grad              9        Never-married
# 1935    90   Private  221832   Bachelors             13   Married-civ-spouse
# ...    ...       ...     ...         ...            ...                  ...
# 609     17   Private  169658        10th              6        Never-married
# 22928   17         ?  332666        10th              6        Never-married
# 19190   17   Private   29571        12th              8        Never-married
# 19206   17   Private  183066        10th              6        Never-married
# 24954   17   Private  160968        11th              7        Never-married
#
# ...

# %% [markdown]
# # Transpose

# %%
df_transpose = df.T
df_transpose

#df.transpose()
# Out:
#                          0                    1                   2      \
# Age                         39                   50                  38
# Workclass            State-gov     Self-emp-not-inc             Private
# FnlWgt                   77516                83311              215646
# Education            Bachelors            Bachelors             HS-grad
# Education Num               13                   13                   9
# Marital Status   Never-married   Married-civ-spouse            Divorced
# Occupation        Adm-clerical      Exec-managerial   Handlers-cleaners
# Relationship     Not-in-family              Husband       Not-in-family
# Race                     White                White               White
# Sex                       Male                 Male                Male
# Capital Gain              2174                    0                   0
# Capital Loss                 0                    0                   0
# ...

# %% [markdown]
# # Melting

# %%
df_melting=pd.melt(df,id_vars=['Workclass','Education'],var_name='Metric',value_name='value')
df_melting
# Out:
#                 Workclass    Education  Metric   value
# 0               State-gov    Bachelors     Age      39
# 1        Self-emp-not-inc    Bachelors     Age      50
# 2                 Private      HS-grad     Age      38
# 3                 Private         11th     Age      53
# 4                 Private    Bachelors     Age      28
# ...                   ...          ...     ...     ...
# 423288            Private   Assoc-acdm  Income   <=50K
# 423289            Private      HS-grad  Income    >50K
# 423290            Private      HS-grad  Income   <=50K
# 423291            Private      HS-grad  Income   <=50K
# 423292       Self-emp-inc      HS-grad  Income    >50K
#
# [423293 rows x 4 columns]

# %% [markdown]
# # Casting

# %%
df_casting=pd.pivot_table(df,index=['Workclass','Occupation'],values=['Hours Per Week'], aggfunc=list)
df_casting
# Out:
#                                                                     Hours Per Week
# Workclass    Occupation
#  ?            ?                  [60, 40, 40, 2, 32, 40, 40, 45, 20, 50, 40, 40...
#  Federal-gov  Adm-clerical       [40, 42, 40, 15, 40, 40, 60, 80, 40, 43, 40, 4...
#               Armed-Forces                     [40, 60, 50, 40, 40, 40, 48, 40, 8]
#               Craft-repair       [40, 50, 40, 40, 36, 43, 40, 40, 40, 40, 40, 4...
#               Exec-managerial    [55, 42, 55, 40, 58, 40, 40, 40, 48, 40, 40, 5...
# ...                                                                            ...
#  Without-pay  Farming-fishing                             [50, 20, 10, 50, 65, 25]
#               Handlers-cleaners                                               [40]
#               Machine-op-inspct                                               [25]
#               Other-service                                                   [55]
# ...
