# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../DSBDAL_Exam_DataSets/Movie/movies_metadata.csv')
df.head()
# Out:
# C:\Users\shail\AppData\Local\Temp\ipykernel_12056\3483251656.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../DSBDAL_Exam_DataSets/Movie/movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
df = pd.read_csv('../DSBDAL_Exam_DataSets/Movie/movies_metadata.csv', low_memory=False)
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# # Subsets

# %%
df['original_language'].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, '104.0', 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo',
#        'ay', 'kn', 'eu', 'ne', 'pa', 'ky', 'gl', '68.0', 'uz', 'sm', 'mt',
#        '82.0', 'hy', 'iu', 'lb', 'si'], dtype=object)

# %%
df_en = df[df['original_language'] == 'en']
df_en
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45459  False                                                NaN         0
# 45460  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df_fr = df[df['original_language'] == 'fr']
df_fr
# Out:
#        adult belongs_to_collection    budget  \
# 28     False                   NaN  18000000
# 32     False                   NaN         0
# 58     False                   NaN         0
# 67     False                   NaN         0
# 72     False                   NaN         0
# ...      ...                   ...       ...
# 45444  False                   NaN         0
# 45447  False                   NaN         0
# 45448  False                   NaN         0
# 45450  False                   NaN         0
# 45451  False                   NaN         0
#
#                                                   genres homepage      id  \
# 28     [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN     902
# 32     [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...      NaN   78802
# 58     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...      NaN   99040
# 67     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN    4482
# ...

# %%
df_it = df[df['original_language'] == 'it']
df_it
# Out:
#        adult belongs_to_collection budget  \
# 52     False                   NaN      0
# 57     False                   NaN      0
# 122    False                   NaN      0
# 129    False                   NaN      0
# 224    False                   NaN      0
# ...      ...                   ...    ...
# 45115  False                   NaN      0
# 45149  False                   NaN      0
# 45165  False                   NaN      0
# 45276  False                   NaN      0
# 45455  False                   NaN      0
#
#                                                   genres homepage      id  \
# 52     [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN   49133
# 57     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   11010
# 122    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   37975
# 129    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   73067
# 224    [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...      NaN   62488
# ...

# %% [markdown]
# # Merge

# %%
df_merge1 = pd.concat([df_en, df_fr])
df_merge1
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45444  False                                                NaN         0
# 45447  False                                                NaN         0
# 45448  False                                                NaN         0
# 45450  False                                                NaN         0
# 45451  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df_merge2 = pd.concat([df_it, df_fr])
df_merge2
# Out:
#        adult belongs_to_collection budget  \
# 52     False                   NaN      0
# 57     False                   NaN      0
# 122    False                   NaN      0
# 129    False                   NaN      0
# 224    False                   NaN      0
# ...      ...                   ...    ...
# 45444  False                   NaN      0
# 45447  False                   NaN      0
# 45448  False                   NaN      0
# 45450  False                   NaN      0
# 45451  False                   NaN      0
#
#                                                   genres homepage      id  \
# 52     [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN   49133
# 57     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   11010
# 122    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   37975
# 129    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   73067
# 224    [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...      NaN   62488
# ...

# %%
df_merge3 = pd.concat([df_en, df_it])
df_merge3
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45115  False                                                NaN         0
# 45149  False                                                NaN         0
# 45165  False                                                NaN         0
# 45276  False                                                NaN         0
# 45455  False                                                NaN         0
#
#                                                   genres  \
# ...

# %% [markdown]
# # Sort

# %%
df_sort = df.sort_values('vote_average')
df_sort
# Out:
#                                                    adult  \
# 45465                                              False
# 24507                                              False
# 24506                                              False
# 24498                                              False
# 24497                                              False
# ...                                                  ...
# 19730                                 - Written by Ørnås
# 29502                                              False
# 29503   Rune Balot goes to a casino connected to the ...
# 35586                                              False
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#                                    belongs_to_collection  \
# 45465                                                NaN
# 24507  {'id': 38451, 'name': 'Charlie Chan (Warner Ol...
# 24506                                                NaN
# ...

# %%
df_sort = df.sort_values('vote_average', ascending=False)
df_sort
# Out:
#                                                    adult  \
# 21642                                              False
# 15710                                              False
# 22396                                              False
# 22395                                              False
# 35343                                              False
# ...                                                  ...
# 19730                                 - Written by Ørnås
# 29502                                              False
# 29503   Rune Balot goes to a casino connected to the ...
# 35586                                              False
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#                                    belongs_to_collection  \
# 21642                                                NaN
# 15710                                                NaN
# 22396                                                NaN
# ...

# %% [markdown]
# # Transpose

# %%
df.T

#df.transpose()
# Out:
#                                                                    0      \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
# id                                                                   862
# imdb_id                                                        tt0114709
# original_language                                                     en
# original_title                                                 Toy Story
# overview               Led by Woody, Andy's toys live happily in his ...
# popularity                                                     21.946943
# poster_path                             /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# ...

# %% [markdown]
# # Melting

# %%
df_melt = pd.melt(df, id_vars=['id', 'original_language'], var_name='Metric')
df_melt
# Out:
#              id original_language      Metric  value
# 0           862                en       adult  False
# 1          8844                en       adult  False
# 2         15602                en       adult  False
# 3         31357                en       adult  False
# 4         11862                en       adult  False
# ...         ...               ...         ...    ...
# 1000247  439050                fa  vote_count    1.0
# 1000248  111109                tl  vote_count    3.0
# 1000249   67758                en  vote_count    6.0
# 1000250  227506                en  vote_count    0.0
# 1000251  461257                en  vote_count    0.0
#
# [1000252 rows x 4 columns]

# %% [markdown]
# # Casting

# %%
df_cast = pd.pivot_table(df, index=['id','original_language'], values=['original_title','spoken_languages'], aggfunc=list)
df_cast
# Out:
#                                                  original_title  \
# id     original_language
# 100    en                 [Lock, Stock and Two Smoking Barrels]
# 10000  es                           [La estrategia del caracol]
# 10001  en                                      [Young Einstein]
# 100010 en                                      [Flight Command]
# 100017 de                                            [Verfolgt]
# ...                                                         ...
# 99946  en                                        [Exit Smiling]
# 9995   en                                          [Turn It Up]
# 9997   ab                                             [Gabriel]
# 99977  en                                           [Hot Stuff]
# 9999   de                                     [Der freie Wille]
#
#                                                            spoken_languages
# id     original_language
# ...
